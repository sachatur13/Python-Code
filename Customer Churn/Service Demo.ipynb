# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns',None)
import matplotlib.pyplot as plt

# %%
churn_data = pd.read_csv('C:\\Users\\saket\\Desktop\\Online Courses\\Python code\\Customer Churn\\CustomerChurn.csv')

# %%
churn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
# State           3333 non-null object
# act len         3333 non-null int64
# acode           3333 non-null int64
# phone           3333 non-null object
# intpln          3333 non-null object
# vm              3333 non-null object
# #vmail          3333 non-null int64
# day min         3333 non-null float64
# #day            3333 non-null int64
# day charge      3333 non-null float64
# eve min         3333 non-null float64
# #eve            3333 non-null int64
# eve charge      3333 non-null float64
# night min       3333 non-null float64
# #night          3333 non-null int64
# night charge    3333 non-null float64
# intl min        3333 non-null float64
# #intl           3333 non-null int64
# intl charge     3333 non-null float64
# cs calls        3333 non-null int64
# churn           3333 non-null bool
# dtypes: bool(1), float64(8), int64(8), object(4)
# ...

# %%
churn_data.rename(columns = {'vmail count':'#vmail','day calls':'#day','eve calls':'#eve','night calls':'#night','intl calls':'#intl'
                          },inplace = True)

# %%
churn_data.head()
# Out:
#   State  act len  acode phone intpln voice mail  vmail count  day min  \
# 0    KS      128    415     Y     no        yes           25    265.1
# 1    OH      107    415     Y     no        yes           26    161.6
# 2    NJ      137    415     Y     no         no            0    243.4
# 3    OH       84    408     Y    yes         no            0    299.4
# 4    OK       75    415     Y    yes         no            0    166.7
#
#    day calls  total day charge  eve min  eve calls  eve charge  night min  \
# 0        110             45.07    197.4         99       16.78      244.7
# 1        123             27.47    195.5        103       16.62      254.4
# 2        114             41.38    121.2        110       10.30      162.6
# 3         71             50.90     61.9         88        5.26      196.9
# 4        113             28.34    148.3        122       12.61      186.9
#
#    night calls  night charge  intl min  intl calls  intl charge  cs calls  \
# ...

# %%
churn_data['phone number'] =np.where(churn_data['phone number'].isnull(),'N','Y')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'phone number'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-df5e358c549e> in <module>()
# ...

# %%
import seaborn as sns

# %%
churn_data['churn'].value_counts().plot(kind='bar')

# %%
churn_data.describe()
# Out:
#            act len        acode  vmail count      day min    day calls  \
# count  3333.000000  3333.000000  3333.000000  3333.000000  3333.000000
# mean    101.064806   437.182418     8.099010   179.775098   100.435644
# std      39.822106    42.371290    13.688365    54.467389    20.069084
# min       1.000000   408.000000     0.000000     0.000000     0.000000
# 25%      74.000000   408.000000     0.000000   143.700000    87.000000
# 50%     101.000000   415.000000     0.000000   179.400000   101.000000
# 75%     127.000000   510.000000    20.000000   216.400000   114.000000
# max     243.000000   510.000000    51.000000   350.800000   165.000000
#
#        total day charge      eve min    eve calls   eve charge    night min  \
# count       3333.000000  3333.000000  3333.000000  3333.000000  3333.000000
# mean          30.562307   200.980348   100.114311    17.083540   200.872037
# std            9.259435    50.713844    19.922625     4.310668    50.573847
# ...

# %%
import matplotlib as mpl
with mpl.rc_context():
    mpl.rc("figure",figsize = (40,40))
    plt.matshow(churn_data.corr())
    plt.xticks(range(len(churn_data.columns)),churn_data.columns)
    plt.yticks(range(len(churn_data.columns)),churn_data.columns)
    plt.colorbar()
    plt.show()
